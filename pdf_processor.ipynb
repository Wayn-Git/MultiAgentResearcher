# %%
import pdfplumber
import os

# %%
pdf_path = "2601.00030v1.pdf"

print(os.path)
# Out:
# <module 'ntpath' from 'c:\\Users\\Wayne\\AppData\\Local\\Programs\\Python\\Python310\\lib\\ntpath.py'>

# %%
class pdf_processor:
    def __init__(self, file_path, output_path):
        self.file_path = file_path
        self.output_path = output_path
    
    def pdf_to_txt(self):
        if not self.file_path:
            print("Error: No file path provided.")
            return self.output_path = os.path
             
        
        if not self.output_path:
            print("Error: No output path provided. Creating Folder 'txt_file'")
            return 
            self.output_path = ""

        if not self.file_path.lower().endswith('.pdf'):
            print(f"Error: {self.file_path} is not a PDF file.")
            return
        
        
        with pdfplumbler.open(self.file_path) as pdf, open(self.output_path, 'w', encoding='utf-8') as txt_file:
            try:
                for page in pdf.pages:
                    text = page.extract_text()
                if text:
                    txt_file.write(text + '\n')
            except Exception as e:
                print(f"Error processing {self.file_path}: {e}")
            except Exception as e:
# Out:
#   Cell In[3], line 9
#     return self.output_path = os.path
#                             ^
# SyntaxError: invalid syntax
